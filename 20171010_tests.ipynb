# %% [markdown]
# Import some data using python scientific libraries.

# %%
import pandas as pd
import os

TODAY_DATA = os.path.join("..", "20171010", "prj1", "data")
# print(os.listdir(TODAY_DATA))

# read_table = pd.io.parsers.read_table
# read_csv = pd.io.parsers.read_csv

ld_genetics_df = pd.read_table(os.path.join(TODAY_DATA, "ld_genetics.txt"))
# dtype=object to have integers and NaNs together (NaNs are not currently available among integers)
ebola_df = pd.read_csv(os.path.join(TODAY_DATA, "country_timeseries.csv"), parse_dates=["Date"])

# print(ld_genetics_df.dtypes)
ebola_df.head(10)
# Out:
#         Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0 2015-01-05  289        2776.0            NaN            10030.0
# 1 2015-01-04  288        2775.0            NaN             9780.0
# 2 2015-01-03  287        2769.0         8166.0             9722.0
# 3 2015-01-02  286           NaN         8157.0                NaN
# 4 2014-12-31  284        2730.0         8115.0             9633.0
# 5 2014-12-28  281        2706.0         8018.0             9446.0
# 6 2014-12-27  280        2695.0            NaN             9409.0
# 7 2014-12-24  277        2630.0         7977.0             9203.0
# 8 2014-12-21  273        2597.0            NaN             9004.0
# 9 2014-12-20  272        2571.0         7862.0             8939.0
#
#    Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  Cases_Mali  \
# 0            NaN            NaN                 NaN          NaN         NaN
# 1            NaN            NaN                 NaN          NaN         NaN
# ...
