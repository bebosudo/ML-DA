# %% [markdown]
# # SVM kernels
#
# consider versicolor vs virginica+setosa using only petal info:
#
# * use different kernels
# * draw decision boundaries
# * play with params

# %%
import pandas as pd

df = pd.read_csv("https://forge.scilab.org/index.php/p/rdataset/source/file/master/csv/datasets/iris.csv",
                 index_col=0, skiprows=1,
                 names=['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species'])

df.drop(['sepal_length', 'sepal_width'], axis=1, inplace=True)

df['species'] = df['species'].apply(lambda spec: "virginica+setosa" if spec != "versicolor" else spec)

df[df['species'] != 'versicolor']
# Out:
#      petal_length  petal_width           species
# 1             1.4          0.2  virginica+setosa
# 2             1.4          0.2  virginica+setosa
# 3             1.3          0.2  virginica+setosa
# 4             1.5          0.2  virginica+setosa
# 5             1.4          0.2  virginica+setosa
# 6             1.7          0.4  virginica+setosa
# 7             1.4          0.3  virginica+setosa
# 8             1.5          0.2  virginica+setosa
# 9             1.4          0.2  virginica+setosa
# 10            1.5          0.1  virginica+setosa
# 11            1.5          0.2  virginica+setosa
# 12            1.6          0.2  virginica+setosa
# 13            1.4          0.1  virginica+setosa
# 14            1.1          0.1  virginica+setosa
# 15            1.2          0.2  virginica+setosa
# 16            1.5          0.4  virginica+setosa
# 17            1.3          0.4  virginica+setosa
# 18            1.4          0.3  virginica+setosa
# ...
